# %% [markdown]
# # 🏆 Segmentation 모델 평가 프레임워크
#
# ## 폴더 구조
# ```
# eval_dataset/
# ├── image_001/
# │   ├── image_001.jpg
# │   └── gt_masks/
# │       ├── laptop.png   ← 흰색=객체, 검정=배경
# │       └── mouse.png
# ├── image_002/ ...
# ```
#
# ## 새 모델 추가 방법
# **STEP 1 셀**에서 함수 하나만 추가하고 `MODELS`에 등록하세요.
# ```python
# def my_model(img_path, W, H):
#     return [
#         {'label': 'laptop', 'confidence': 0.92, 'mask': np.ndarray(bool, shape H×W)},
#     ]
#
# MODELS = {
#     'YOLO11x': model_yolo,
#     'MyModel': my_model,
# }
# ```
#
# MODELS 내부에 이름과 정보를 넣어주어야 함 ('이름' : 정보)
#
# 정보에는 label, confidence, mask가 필요함.
#
# ![image.png](attachment:30568e76-d9ad-46e4-8469-90ffbb2141d2.png)

# %%
# !pip install "ultralytics>=8.3.0" opencv-python-headless matplotlib numpy koreanize-matplotlib -q

# %%
import sys
import warnings
import datetime
from pathlib import Path
from collections import defaultdict

import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.colors as mcolors
from ultralytics import YOLO
DEBUG_DIR = Path("debug_crop_check")
DEBUG_DIR.mkdir(exist_ok=True)

warnings.filterwarnings('ignore')

try:
    from koreanize_matplotlib import koreanize
    koreanize()
except ImportError:
    pass

print(f'Python: {sys.version}')
# Out:
# Python: 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]

# %% [markdown]
# ---
# ## ✏️ INPUT — 설정

# %%
# ✏️ 여기만 수정
EVAL_DATASET_DIR = 'eval_dataset'
OUTPUT_DIR       = 'results'   # None → 날짜시간 자동 생성

# 출력 폴더 생성
if OUTPUT_DIR is None:
    OUTPUT_DIR = 'results_' + datetime.datetime.now().strftime('%Y%m%d_%H%M%S')
OUT = Path(OUTPUT_DIR)
OUT.mkdir(exist_ok=True)

# 데이터셋 스캔
root = Path(EVAL_DATASET_DIR)
if not root.exists():
    raise FileNotFoundError(f"'{EVAL_DATASET_DIR}' 폴더가 없습니다.")

data_dirs = sorted(d for d in root.iterdir() if d.is_dir())
if not data_dirs:
    raise ValueError(f"'{EVAL_DATASET_DIR}' 안에 하위 폴더가 없습니다.")

print(f'📁 출력 폴더 : {OUT.resolve()}')
print(f'📂 데이터 수 : {len(data_dirs)}개')
for d in data_dirs:
    imgs  = list(d.glob('*.jpg')) + list(d.glob('*.png'))
    masks = list((d / 'gt_masks').glob('*.png')) if (d / 'gt_masks').exists() else []
    print(f'   📁 {d.name:30} | 이미지:{len(imgs)}  GT마스크:{len(masks)}')
# Out:
# 📁 출력 폴더 : C:\Users\hwapyeong\Documents\computer_vision\Rating_Batch_comparison\Rating_Batch_comparison\results
# 📂 데이터 수 : 6개
#    📁 image_001                      | 이미지:1  GT마스크:9
#    📁 image_002                      | 이미지:1  GT마스크:7
#    📁 image_003                      | 이미지:1  GT마스크:8
#    📁 image_004                      | 이미지:1  GT마스크:8
#    📁 image_005                      | 이미지:1  GT마스크:6
#    📁 image_006                      | 이미지:1  GT마스크:8

# %% [markdown]
# ---
# ## ✏️ STEP 1 — 모델 등록
#
# - 각 모델을 함수로 정의 후 `MODELS` 딕셔너리에 등록
# - **YOLO는 기본 제공** — 다른 모델은 아래 템플릿을 복사해서 추가
# - 반환 형태: `[{'label': str, 'confidence': float, 'mask': bool ndarray(H,W)}, ...]`

# %%
# ─────────────────────────────────────────────────────────
# 공통 YOLO 추론 헬퍼 — 코드 중복 제거
# ─────────────────────────────────────────────────────────
def _run_yolo(yolo_model, img_input, W, H,
              conf=0.15, iou=0.40, imgsz=1280):
    """YOLO 모델 추론 → 공통 반환 형태 리스트"""
    res        = yolo_model(img_input, conf=conf, iou=iou, imgsz=imgsz,
                            retina_masks=True, verbose=False)[0]
    masks_data = res.masks.data.cpu().numpy() if res.masks is not None else None
    out = []
    for i, box in enumerate(res.boxes):
        mask = None
        if masks_data is not None:
            m    = cv2.resize(masks_data[i], (W, H), interpolation=cv2.INTER_LINEAR)
            mask = m > 0.5
        out.append({
            'label'     : yolo_model.names[int(box.cls[0].item())],
            'confidence': float(box.conf[0].item()),
            'mask'      : mask,
        })
    return out


# ─────────────────────────────────────────────────────────
# 모델 A — YOLO11x-seg (기본 제공)
# ─────────────────────────────────────────────────────────
_yolo_x = YOLO('yolo11x-seg.pt')

def model_yolo(img_path, W, H):
    return _run_yolo(_yolo_x, img_path, W, H)


# ─────────────────────────────────────────────────────────
# 모델 B — YOLO11n-seg
# ─────────────────────────────────────────────────────────
_yolo_bh = YOLO('best_FT_ epoch10_bh.pt')

def model_yolo1(img_path, W, H):
    return _run_yolo(_yolo_bh, img_path, W, H)

_yolo_full = YOLO('best_FT_epoch5_full.pt')

def model_yolo2(img_path, W, H):
    return _run_yolo(_yolo_full, img_path, W, H)

_yolo_26x = YOLO('yolo26x-seg.pt')

def model_yolo3(img_path, W, H):
    return _run_yolo(_yolo_26x, img_path, W, H)

_yolo_coco_stopped = YOLO('best_FT_stoopped.pt')

def model_yolo4(img_path, W, H):
    return _run_yolo(_yolo_coco_stopped, img_path, W, H)

_yolo_coco_full = YOLO('best_FT_coco_full_bal.pt')

def model_yolo5(img_path, W, H):
    return _run_yolo(_yolo_coco_full, img_path, W, H)

_yolo_11n = YOLO('yolo11n-seg.pt')

def model_yolo6(img_path, W, H):
    return _run_yolo(_yolo_11n, img_path, W, H)

# ─────────────────────────────────────────────────────────
# ✏️ 평가할 모델 등록 (이름: 함수)
# ─────────────────────────────────────────────────────────
MODELS = {
    'YOLO11x-seg': model_yolo,
    'YOLO11-bh': model_yolo1,
    'YOLO11-full': model_yolo2,
    'YOLO26x-seg': model_yolo3,
    'YOLO_coco_stop-seg': model_yolo4,
    'YOLO_coco_full-seg': model_yolo5,
    'YOLO11n-seg': model_yolo6,
}

print(f'✅ 등록된 모델: {list(MODELS.keys())}')
# Out:
# ✅ 등록된 모델: ['YOLO11x-seg', 'YOLO11-bh', 'YOLO11-full', 'YOLO26x-seg', 'YOLO_coco_stop-seg', 'YOLO_coco_full-seg', 'YOLO11n-seg']

# %% [markdown]
# ---
# ## STEP 2 — 배치 평가 실행
#
# 등록된 모든 모델을 동일한 dataset으로 자동 평가합니다.
# **이 셀은 수정할 필요 없습니다.**

# %%
# ── 평가 유틸 함수 ──────────────────────────────────────────
def detect_table_and_crop(image):
    
    # 1. grayscale 변환
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # 2. blur (노이즈 감소)
    blur = cv2.GaussianBlur(gray, (5,5), 0)

    # 3. 밝은 영역 threshold (흰색 책상)
    _, thresh = cv2.threshold(blur, 200, 255, cv2.THRESH_BINARY)

    # 4. morphology (작은 노이즈 제거)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (31, 31))
    thresh = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=2)
    thresh = cv2.morphologyEx(thresh, cv2.MORPH_DILATE, kernel, iterations=3)


    # 5. contour 찾기
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if len(contours) == 0:
        print("책상 영역을 찾지 못했습니다.")
        return None, None

    # 6. 가장 큰 contour = 책상
    table_contour = max(contours, key=cv2.contourArea)

    # 7. bounding box 생성
    x, y, w, h = cv2.boundingRect(table_contour)

    # 8. crop
    cropped = image[y:y+h, x:x+w]

    return cropped, (x, y, w, h)
def compute_iou(a: np.ndarray, b: np.ndarray) -> float:
    a = np.squeeze(a)
    b = np.squeeze(b)

    i = np.logical_and(a, b).sum()
    u = np.logical_or(a, b).sum()
    return float(i / u) if u > 0 else 0.0


def compute_precision_recall(gt_mask, pred_mask):
    intersection = np.logical_and(gt_mask, pred_mask).sum()
    precision = float(intersection / pred_mask.sum()) if pred_mask.sum() > 0 else 0.0
    recall    = float(intersection / gt_mask.sum())   if gt_mask.sum()  > 0 else 0.0
    return precision, recall


import re

def crop_with_bbox(image, bbox):
    x, y, w, h = bbox
    return image[y:y+h, x:x+w]


def load_gt_masks(gt_dir: Path, crop_bbox, W: int, H: int) -> list:
    """GT 마스크 PNG 파일들을 읽고 같은 bbox로 crop해서 반환"""
    result = []
    for f in sorted(gt_dir.glob('*.png')):
        label = re.sub(r'_\d+$', '', f.stem).replace('_', ' ')

        raw = cv2.imread(str(f), cv2.IMREAD_GRAYSCALE)
        if raw is None:
            print(f'  ⚠️  마스크 로드 실패: {f}')
            continue

        cropped = crop_with_bbox(raw, crop_bbox)

        if cropped.shape[:2] != (H, W):
            cropped = cv2.resize(cropped, (W, H), interpolation=cv2.INTER_NEAREST)

        # 여기 2줄 추가
        if cropped.ndim == 3:
            cropped = cropped[..., 0]

        result.append({
            'label': label,
            'mask': (cropped > 127).squeeze()
        })
    return result


def match_and_score(gt_masks: list, detections: list) -> list:
    """GT 마스크와 탐지 결과를 매칭하여 평가 결과 반환"""
    # 인덱스 부여 (원본 리스트 보호)
    detections = [{**d, '_idx': i} for i, d in enumerate(detections)]
    used    = set()
    results = []

    for gt in gt_masks:
        gt_label, gt_mask = gt['label'], gt['mask']
        best_iou, best_det = -1.0, None

        # 1순위: 같은 레이블 중 IoU 최대
        for d in detections:
            if d['_idx'] in used or d['label'] != gt_label or d['mask'] is None:
                continue
            iou = compute_iou(gt_mask, d['mask'])
            if iou > best_iou:
                best_iou, best_det = iou, d

        # 2순위: 마스크 겹침 기준 fallback
        if best_det is None:
            for d in detections:
                if d['_idx'] in used or d['mask'] is None:
                    continue
                iou = compute_iou(gt_mask, d['mask'])
                if iou > best_iou:
                    best_iou, best_det = iou, d
            if best_det is not None and best_iou <= 0.0:
                best_det = None

        if best_det is not None:
            used.add(best_det['_idx'])
            precision, recall = compute_precision_recall(gt_mask, best_det['mask'])
            results.append({
                'gt_label'  : gt_label,
                'pred_label': best_det['label'],
                'confidence': best_det['confidence'],
                'iou'       : best_iou,
                'precision' : precision,
                'recall'    : recall,
                'score'     : best_iou * best_det['confidence'],
                'matched'   : True,
            })
        else:
            results.append({
                'gt_label'  : gt_label,
                'pred_label': None,
                'confidence': 0.0,
                'iou'       : 0.0,
                'precision' : 0.0,
                'recall'    : 0.0,
                'score'     : 0.0,
                'matched'   : False,
            })
    return results


def _get_image_file(data_dir: Path):
    """폴더에서 이미지 파일 하나를 찾아 반환 (없으면 None)"""
    imgs = ([f for f in data_dir.glob('*.jpg')] +
            [f for f in data_dir.glob('*.png') if 'gt_masks' not in str(f)])
    return imgs[0] if imgs else None


# ── 모델별 전체 배치 평가 ────────────────────────────────────────────────────
ALL_RESULTS = {}  # { 'ModelName': [이미지별 결과, ...] }

for model_name, model_fn in MODELS.items():
    print(f'\n{"="*65}')
    print(f'  🤖 {model_name} 평가 중...')
    print(f'{"="*65}')
    img_results = []

    for data_dir in data_dirs:
        gt_mask_dir = data_dir / 'gt_masks'
        img_path    = _get_image_file(data_dir)
        if img_path is None or not gt_mask_dir.exists():
            continue

        img_bgr = cv2.imread(str(img_path))
        if img_bgr is None:
            print(f'  ⚠️  이미지 로드 실패: {img_path}')
            continue

        # 원본 이미지 crop
        cropped_img, crop_bbox = detect_table_and_crop(img_bgr)

        # crop 실패 시 원본 사용
        if cropped_img is None or crop_bbox is None:
            cropped_img = img_bgr
            crop_bbox = (0, 0, img_bgr.shape[1], img_bgr.shape[0])

        H, W = cropped_img.shape[:2]

        # crop된 이미지를 모델 입력으로 사용
        detections = model_fn(cropped_img, W, H)

        # GT 마스크도 같은 bbox로 crop
        gt_masks = load_gt_masks(gt_mask_dir, crop_bbox, W, H)

       # =========================
        # 디버그 이미지 저장
        # =========================

        sample_dir = DEBUG_DIR / data_dir.name
        model_input_dir = sample_dir / "00_model_input"
        bbox_dir        = sample_dir / "01_bbox"
        gt_mask_dir_dbg = sample_dir / "02_gt_mask"
        overlay_dir     = sample_dir / "03_overlay"

        model_input_dir.mkdir(parents=True, exist_ok=True)
        bbox_dir.mkdir(parents=True, exist_ok=True)
        gt_mask_dir_dbg.mkdir(parents=True, exist_ok=True)
        overlay_dir.mkdir(parents=True, exist_ok=True)

        # 1. 모델에 실제 들어간 crop 이미지 저장
        cv2.imwrite(
            str(model_input_dir / "model_input.jpg"),
            cropped_img
        )

        # 2. 원본에서 crop된 bbox 저장
        x, y, w, h = crop_bbox
        bbox_img = img_bgr.copy()
        cv2.rectangle(bbox_img, (x, y), (x + w, y + h), (0, 255, 0), 3)
        cv2.imwrite(
            str(bbox_dir / "bbox.jpg"),
            bbox_img
        )

        # 3. crop된 GT mask / overlay 저장
        for idx, gt in enumerate(gt_masks):
            label = gt["label"]
            gt_mask = np.squeeze(gt["mask"]).astype(np.uint8) * 255

            # 같은 클래스가 여러 개면 파일명 안 겹치게 idx 포함
            cv2.imwrite(
                str(gt_mask_dir_dbg / f"{idx:02d}_{label}.png"),
                gt_mask
            )

            overlay = cropped_img.copy()
            mask_bool = np.squeeze(gt["mask"]).astype(bool)
            overlay[mask_bool] = (0, 0, 255)
            blended = cv2.addWeighted(cropped_img, 0.7, overlay, 0.3, 0)

            cv2.imwrite(
                str(overlay_dir / f"{idx:02d}_{label}.jpg"),
                blended
            )

        # 평가
        eval_rs = match_and_score(gt_masks, detections)

        img_score = float(np.mean([r['score'] for r in eval_rs])) if eval_rs else 0.0
        correct   = sum(1 for r in eval_rs if r['gt_label'] == r['pred_label'])

        img_results.append({
            'name'        : data_dir.name,
            'eval_results': eval_rs,
            'img_score'   : img_score,
            'correct'     : correct,
            'total'       : len(eval_rs),
        })

        print(f'  📁 {data_dir.name}')
        for r in eval_rs:
            pred = r['pred_label'] or '미탐지'
            mark = '⭕' if r['gt_label'] == r['pred_label'] else '❌'
            print(f'     {mark} {r["gt_label"]:20} → {pred:20} | IoU:{r["iou"]:.3f}  score:{r["score"]:.3f}')
        print(f'     정답 {correct}/{len(eval_rs)}  img_score:{img_score:.4f}\n')

    ALL_RESULTS[model_name] = img_results

print('✅ 전체 평가 완료')
# Out:
# =================================================================
#   🤖 YOLO11x-seg 평가 중...
# =================================================================
#   📁 image_001
#      ⭕ book                 → book                 | IoU:0.971  score:0.752
#      ❌ bottle               → scissors             | IoU:0.003  score:0.002
#      ❌ hair drier           → keyboard             | IoU:0.001  score:0.001
#      ⭕ handbag              → handbag              | IoU:0.851  score:0.804
#      ❌ keyboard             → chair                | IoU:0.004  score:0.001
#      ❌ mouse                → 미탐지                  | IoU:0.000  score:0.000
#      ❌ mouse                → 미탐지                  | IoU:0.000  score:0.000
#      ❌ scissors             → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ toothbrush           → toothbrush           | IoU:0.474  score:0.106
#      정답 3/9  img_score:0.1852
#
#   📁 image_002
#      ⭕ book                 → book                 | IoU:0.898  score:0.141
#      ❌ bottle               → keyboard             | IoU:0.001  score:0.001
#      ❌ hair drier           → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ keyboard             → keyboard             | IoU:0.574  score:0.531
#      ⭕ mouse                → mouse                | IoU:0.407  score:0.382
#      ⭕ scissors             → scissors             | IoU:0.762  score:0.735
#      ⭕ toothbrush           → toothbrush           | IoU:0.510  score:0.376
#      정답 5/7  img_score:0.3094
#
#   📁 image_003
#      ⭕ book                 → book                 | IoU:0.975  score:0.475
#      ❌ bottle               → 미탐지                  | IoU:0.000  score:0.000
#      ❌ hair drier           → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ handbag              → handbag              | IoU:0.987  score:0.939
#      ⭕ keyboard             → keyboard             | IoU:0.942  score:0.888
#      ⭕ mouse                → mouse                | IoU:0.647  score:0.471
#      ⭕ scissors             → scissors             | IoU:0.924  score:0.888
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      정답 5/8  img_score:0.4577
#
#   📁 image_004
#      ⭕ book                 → book                 | IoU:0.968  score:0.413
#      ⭕ cell phone           → cell phone           | IoU:0.922  score:0.499
#      ❌ hair drier           → toothbrush           | IoU:0.000  score:0.000
#      ❌ handbag              → keyboard             | IoU:0.000  score:0.000
#      ❌ keyboard             → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ scissors             → scissors             | IoU:0.694  score:0.656
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      정답 3/8  img_score:0.1960
#
#   📁 image_005
#      ⭕ book                 → book                 | IoU:0.676  score:0.641
#      ❌ bottle               → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ cell phone           → cell phone           | IoU:0.507  score:0.109
#      ⭕ keyboard             → keyboard             | IoU:0.952  score:0.904
#      ⭕ scissors             → scissors             | IoU:0.738  score:0.696
#      ⭕ toothbrush           → toothbrush           | IoU:0.446  score:0.372
#      정답 5/6  img_score:0.4536
#
#   📁 image_006
#      ⭕ book                 → book                 | IoU:0.976  score:0.247
#      ❌ bottle               → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ cell phone           → cell phone           | IoU:0.964  score:0.735
#      ⭕ keyboard             → keyboard             | IoU:0.916  score:0.838
#      ⭕ laptop               → laptop               | IoU:0.943  score:0.775
#      ⭕ scissors             → scissors             | IoU:0.916  score:0.880
#      ⭕ toothbrush           → toothbrush           | IoU:0.000  score:0.000
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      정답 6/8  img_score:0.4343
#
#
# =================================================================
#   🤖 YOLO11-bh 평가 중...
# =================================================================
#   📁 image_001
#      ⭕ book                 → book                 | IoU:0.969  score:0.390
#      ⭕ bottle               → bottle               | IoU:0.914  score:0.626
#      ❌ hair drier           → keyboard             | IoU:0.000  score:0.000
#      ⭕ handbag              → handbag              | IoU:0.851  score:0.701
#      ❌ keyboard             → 미탐지                  | IoU:0.000  score:0.000
#      ❌ mouse                → cell phone           | IoU:0.959  score:0.481
#      ❌ mouse                → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ scissors             → scissors             | IoU:0.676  score:0.118
#      ⭕ toothbrush           → toothbrush           | IoU:0.465  score:0.204
#      정답 5/9  img_score:0.2801
#
#   📁 image_002
#      ❌ book                 → handbag              | IoU:0.006  score:0.003
#      ⭕ bottle               → bottle               | IoU:0.632  score:0.145
#      ❌ hair drier           → bottle               | IoU:0.872  score:0.244
#      ⭕ keyboard             → keyboard             | IoU:0.573  score:0.503
#      ⭕ mouse                → mouse                | IoU:0.405  score:0.390
#      ⭕ scissors             → scissors             | IoU:0.745  score:0.668
#      ⭕ toothbrush           → toothbrush           | IoU:0.505  score:0.406
#      정답 5/7  img_score:0.3372
#
#   📁 image_003
#      ❌ book                 → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ bottle               → bottle               | IoU:0.955  score:0.862
#      ❌ hair drier           → mouse                | IoU:0.890  score:0.191
#      ❌ handbag              → backpack             | IoU:0.988  score:0.855
#      ⭕ keyboard             → keyboard             | IoU:0.954  score:0.820
#      ⭕ mouse                → mouse                | IoU:0.650  score:0.530
#      ⭕ scissors             → scissors             | IoU:0.926  score:0.812
#      ⭕ toothbrush           → toothbrush           | IoU:0.834  score:0.221
#      정답 5/8  img_score:0.5363
#
#   📁 image_004
#      ⭕ book                 → book                 | IoU:0.972  score:0.215
#      ⭕ cell phone           → cell phone           | IoU:0.924  score:0.669
#      ❌ hair drier           → knife                | IoU:0.710  score:0.163
#      ⭕ handbag              → handbag              | IoU:0.847  score:0.465
#      ⭕ keyboard             → keyboard             | IoU:0.966  score:0.854
#      ⭕ scissors             → scissors             | IoU:0.697  score:0.601
#      ❌ toothbrush           → mouse                | IoU:0.010  score:0.002
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      정답 5/8  img_score:0.3712
#
#   📁 image_005
#      ⭕ book                 → book                 | IoU:0.651  score:0.583
#      ⭕ bottle               → bottle               | IoU:0.911  score:0.905
#      ⭕ cell phone           → cell phone           | IoU:0.512  score:0.329
#      ⭕ keyboard             → keyboard             | IoU:0.957  score:0.597
#      ⭕ scissors             → scissors             | IoU:0.739  score:0.652
#      ⭕ toothbrush           → toothbrush           | IoU:0.454  score:0.380
#      정답 6/6  img_score:0.5744
#
#   📁 image_006
#      ❌ book                 → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ bottle               → bottle               | IoU:0.961  score:0.580
#      ⭕ cell phone           → cell phone           | IoU:0.967  score:0.223
#      ⭕ keyboard             → keyboard             | IoU:0.869  score:0.481
#      ⭕ laptop               → laptop               | IoU:0.885  score:0.170
#      ⭕ scissors             → scissors             | IoU:0.921  score:0.771
#      ⭕ toothbrush           → toothbrush           | IoU:0.000  score:0.000
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      정답 6/8  img_score:0.2781
#
#
# =================================================================
#   🤖 YOLO11-full 평가 중...
# =================================================================
#   📁 image_001
#      ❌ book                 → laptop               | IoU:0.009  score:0.006
#      ⭕ bottle               → bottle               | IoU:0.000  score:0.000
#      ⭕ hair drier           → hair drier           | IoU:0.822  score:0.709
#      ❌ handbag              → 미탐지                  | IoU:0.000  score:0.000
#      ❌ keyboard             → 미탐지                  | IoU:0.000  score:0.000
#      ❌ mouse                → cell phone           | IoU:0.967  score:0.441
#      ❌ mouse                → 미탐지                  | IoU:0.000  score:0.000
#      ❌ scissors             → toothbrush           | IoU:0.655  score:0.415
#      ⭕ toothbrush           → toothbrush           | IoU:0.448  score:0.426
#      정답 3/9  img_score:0.2220
#
#   📁 image_002
#      ❌ book                 → laptop               | IoU:0.357  score:0.245
#      ⭕ bottle               → bottle               | IoU:0.000  score:0.000
#      ⭕ hair drier           → hair drier           | IoU:0.749  score:0.701
#      ❌ keyboard             → laptop               | IoU:0.308  score:0.063
#      ❌ mouse                → bottle               | IoU:0.501  score:0.098
#      ❌ scissors             → toothbrush           | IoU:0.662  score:0.558
#      ⭕ toothbrush           → toothbrush           | IoU:0.511  score:0.499
#      정답 3/7  img_score:0.3091
#
#   📁 image_003
#      ❌ book                 → laptop               | IoU:0.099  score:0.017
#      ⭕ bottle               → bottle               | IoU:0.936  score:0.918
#      ⭕ hair drier           → hair drier           | IoU:0.790  score:0.781
#      ❌ handbag              → 미탐지                  | IoU:0.000  score:0.000
#      ❌ keyboard             → laptop               | IoU:0.657  score:0.362
#      ❌ mouse                → cell phone           | IoU:0.643  score:0.423
#      ⭕ scissors             → scissors             | IoU:0.921  score:0.549
#      ⭕ toothbrush           → toothbrush           | IoU:0.823  score:0.393
#      정답 4/8  img_score:0.4304
#
#   📁 image_004
#      ❌ book                 → laptop               | IoU:0.606  score:0.127
#      ❌ cell phone           → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ hair drier           → hair drier           | IoU:0.535  score:0.526
#      ❌ handbag              → laptop               | IoU:0.766  score:0.279
#      ❌ keyboard             → zebra                | IoU:0.743  score:0.255
#      ❌ scissors             → toothbrush           | IoU:0.694  score:0.544
#      ⭕ toothbrush           → toothbrush           | IoU:0.680  score:0.660
#      ⭕ toothbrush           → toothbrush           | IoU:0.737  score:0.723
#      정답 3/8  img_score:0.3893
#
#   📁 image_005
#      ❌ book                 → laptop               | IoU:0.064  score:0.026
#      ⭕ bottle               → bottle               | IoU:0.909  score:0.250
#      ⭕ cell phone           → cell phone           | IoU:0.473  score:0.147
#      ❌ keyboard             → laptop               | IoU:0.896  score:0.176
#      ❌ scissors             → toothbrush           | IoU:0.710  score:0.502
#      ⭕ toothbrush           → toothbrush           | IoU:0.409  score:0.404
#      정답 3/6  img_score:0.2510
#
#   📁 image_006
#      ❌ book                 → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ bottle               → bottle               | IoU:0.923  score:0.767
#      ⭕ cell phone           → cell phone           | IoU:0.965  score:0.725
#      ❌ keyboard             → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ laptop               → laptop               | IoU:0.274  score:0.165
#      ⭕ scissors             → scissors             | IoU:0.936  score:0.610
#      ⭕ toothbrush           → toothbrush           | IoU:0.767  score:0.677
#      ⭕ toothbrush           → toothbrush           | IoU:0.808  score:0.754
#      정답 6/8  img_score:0.4622
#
#
# =================================================================
#   🤖 YOLO26x-seg 평가 중...
# =================================================================
#   📁 image_001
#      ⭕ book                 → book                 | IoU:0.975  score:0.751
#      ⭕ bottle               → bottle               | IoU:0.937  score:0.276
#      ❌ hair drier           → keyboard             | IoU:0.000  score:0.000
#      ❌ handbag              → 미탐지                  | IoU:0.000  score:0.000
#      ❌ keyboard             → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ mouse                → mouse                | IoU:0.974  score:0.229
#      ⭕ mouse                → mouse                | IoU:0.974  score:0.419
#      ❌ scissors             → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ toothbrush           → toothbrush           | IoU:0.487  score:0.186
#      정답 5/9  img_score:0.2068
#
#   📁 image_002
#      ⭕ book                 → book                 | IoU:0.948  score:0.705
#      ❌ bottle               → keyboard             | IoU:0.001  score:0.001
#      ❌ hair drier           → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ keyboard             → keyboard             | IoU:0.566  score:0.551
#      ⭕ mouse                → mouse                | IoU:0.405  score:0.390
#      ⭕ scissors             → scissors             | IoU:0.755  score:0.583
#      ⭕ toothbrush           → toothbrush           | IoU:0.528  score:0.233
#      정답 5/7  img_score:0.3519
#
#   📁 image_003
#      ⭕ book                 → book                 | IoU:0.979  score:0.434
#      ⭕ bottle               → bottle               | IoU:0.953  score:0.208
#      ❌ hair drier           → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ handbag              → handbag              | IoU:0.987  score:0.392
#      ⭕ keyboard             → keyboard             | IoU:0.963  score:0.925
#      ⭕ mouse                → mouse                | IoU:0.317  score:0.068
#      ⭕ scissors             → scissors             | IoU:0.924  score:0.841
#      ⭕ toothbrush           → toothbrush           | IoU:0.805  score:0.227
#      정답 7/8  img_score:0.3868
#
#   📁 image_004
#      ⭕ book                 → book                 | IoU:0.970  score:0.866
#      ❌ cell phone           → 미탐지                  | IoU:0.000  score:0.000
#      ❌ hair drier           → 미탐지                  | IoU:0.000  score:0.000
#      ❌ handbag              → keyboard             | IoU:0.000  score:0.000
#      ❌ keyboard             → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ scissors             → scissors             | IoU:0.698  score:0.314
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      정답 2/8  img_score:0.1474
#
#   📁 image_005
#      ⭕ book                 → book                 | IoU:0.685  score:0.655
#      ⭕ bottle               → bottle               | IoU:0.914  score:0.171
#      ⭕ cell phone           → cell phone           | IoU:0.502  score:0.111
#      ⭕ keyboard             → keyboard             | IoU:0.947  score:0.924
#      ⭕ scissors             → scissors             | IoU:0.708  score:0.662
#      ⭕ toothbrush           → toothbrush           | IoU:0.447  score:0.211
#      정답 6/6  img_score:0.4556
#
#   📁 image_006
#      ⭕ book                 → book                 | IoU:0.979  score:0.650
#      ❌ bottle               → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ cell phone           → cell phone           | IoU:0.973  score:0.298
#      ⭕ keyboard             → keyboard             | IoU:0.979  score:0.950
#      ❌ laptop               → book                 | IoU:0.952  score:0.150
#      ⭕ scissors             → scissors             | IoU:0.921  score:0.893
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      정답 4/8  img_score:0.3676
#
#
# =================================================================
#   🤖 YOLO_coco_stop-seg 평가 중...
# =================================================================
#   📁 image_001
#      ❌ book                 → 미탐지                  | IoU:0.000  score:0.000
#      ❌ bottle               → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ hair drier           → hair drier           | IoU:0.423  score:0.073
#      ❌ handbag              → 미탐지                  | IoU:0.000  score:0.000
#      ❌ keyboard             → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ mouse                → mouse                | IoU:0.958  score:0.860
#      ⭕ mouse                → mouse                | IoU:0.960  score:0.712
#      ❌ scissors             → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ toothbrush           → toothbrush           | IoU:0.445  score:0.068
#      정답 4/9  img_score:0.1903
#
#   📁 image_002
#      ❌ book                 → 미탐지                  | IoU:0.000  score:0.000
#      ❌ bottle               → keyboard             | IoU:0.002  score:0.001
#      ❌ hair drier           → keyboard             | IoU:0.003  score:0.001
#      ⭕ keyboard             → keyboard             | IoU:0.579  score:0.125
#      ⭕ mouse                → mouse                | IoU:0.562  score:0.422
#      ⭕ scissors             → scissors             | IoU:0.727  score:0.127
#      ⭕ toothbrush           → toothbrush           | IoU:0.513  score:0.446
#      정답 4/7  img_score:0.1602
#
#   📁 image_003
#      ❌ book                 → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ bottle               → bottle               | IoU:0.939  score:0.252
#      ⭕ hair drier           → hair drier           | IoU:0.736  score:0.116
#      ❌ handbag              → hair drier           | IoU:0.000  score:0.000
#      ⭕ keyboard             → keyboard             | IoU:0.929  score:0.208
#      ⭕ mouse                → mouse                | IoU:0.640  score:0.557
#      ⭕ scissors             → scissors             | IoU:0.940  score:0.890
#      ⭕ toothbrush           → toothbrush           | IoU:0.799  score:0.122
#      정답 6/8  img_score:0.2681
#
#   📁 image_004
#      ❌ book                 → hair drier           | IoU:0.167  score:0.042
#      ❌ cell phone           → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ hair drier           → hair drier           | IoU:0.672  score:0.351
#      ❌ handbag              → keyboard             | IoU:0.001  score:0.000
#      ⭕ keyboard             → keyboard             | IoU:0.860  score:0.184
#      ⭕ scissors             → scissors             | IoU:0.698  score:0.383
#      ⭕ toothbrush           → toothbrush           | IoU:0.000  score:0.000
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      정답 4/8  img_score:0.1201
#
#   📁 image_005
#      ⭕ book                 → book                 | IoU:0.637  score:0.160
#      ⭕ bottle               → bottle               | IoU:0.890  score:0.221
#      ❌ cell phone           → book                 | IoU:0.012  score:0.005
#      ⭕ keyboard             → keyboard             | IoU:0.944  score:0.633
#      ⭕ scissors             → scissors             | IoU:0.668  score:0.664
#      ⭕ toothbrush           → toothbrush           | IoU:0.446  score:0.332
#      정답 5/6  img_score:0.3359
#
#   📁 image_006
#      ❌ book                 → 미탐지                  | IoU:0.000  score:0.000
#      ❌ bottle               → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ cell phone           → cell phone           | IoU:0.932  score:0.158
#      ⭕ keyboard             → keyboard             | IoU:0.938  score:0.162
#      ❌ laptop               → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ scissors             → scissors             | IoU:0.929  score:0.925
#      ⭕ toothbrush           → toothbrush           | IoU:0.000  score:0.000
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      정답 4/8  img_score:0.1557
#
#
# =================================================================
#   🤖 YOLO_coco_full-seg 평가 중...
# =================================================================
#   📁 image_001
#      ⭕ book                 → book                 | IoU:0.920  score:0.195
#      ⭕ bottle               → bottle               | IoU:0.787  score:0.474
#      ⭕ hair drier           → hair drier           | IoU:0.718  score:0.599
#      ❌ handbag              → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ keyboard             → keyboard             | IoU:0.872  score:0.222
#      ⭕ mouse                → mouse                | IoU:0.935  score:0.859
#      ⭕ mouse                → mouse                | IoU:0.945  score:0.818
#      ❌ scissors             → hair drier           | IoU:0.028  score:0.006
#      ⭕ toothbrush           → toothbrush           | IoU:0.418  score:0.082
#      정답 7/9  img_score:0.3617
#
#   📁 image_002
#      ⭕ book                 → book                 | IoU:0.830  score:0.142
#      ❌ bottle               → keyboard             | IoU:0.033  score:0.029
#      ❌ hair drier           → keyboard             | IoU:0.009  score:0.007
#      ⭕ keyboard             → keyboard             | IoU:0.571  score:0.092
#      ⭕ mouse                → mouse                | IoU:0.544  score:0.502
#      ⭕ scissors             → scissors             | IoU:0.738  score:0.247
#      ⭕ toothbrush           → toothbrush           | IoU:0.511  score:0.422
#      정답 5/7  img_score:0.2056
#
#   📁 image_003
#      ❌ book                 → 미탐지                  | IoU:0.000  score:0.000
#      ❌ bottle               → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ hair drier           → hair drier           | IoU:0.764  score:0.729
#      ❌ handbag              → hair drier           | IoU:0.111  score:0.022
#      ⭕ keyboard             → keyboard             | IoU:0.939  score:0.742
#      ⭕ mouse                → mouse                | IoU:0.649  score:0.622
#      ⭕ scissors             → scissors             | IoU:0.938  score:0.700
#      ⭕ toothbrush           → toothbrush           | IoU:0.737  score:0.157
#      정답 5/8  img_score:0.3714
#
#   📁 image_004
#      ⭕ book                 → book                 | IoU:0.736  score:0.149
#      ❌ cell phone           → hair drier           | IoU:0.006  score:0.003
#      ⭕ hair drier           → hair drier           | IoU:0.644  score:0.158
#      ❌ handbag              → keyboard             | IoU:0.001  score:0.000
#      ⭕ keyboard             → keyboard             | IoU:0.894  score:0.195
#      ⭕ scissors             → scissors             | IoU:0.693  score:0.651
#      ⭕ toothbrush           → toothbrush           | IoU:0.000  score:0.000
#      ❌ toothbrush           → hair drier           | IoU:0.033  score:0.008
#      정답 5/8  img_score:0.1454
#
#   📁 image_005
#      ⭕ book                 → book                 | IoU:0.619  score:0.150
#      ⭕ bottle               → bottle               | IoU:0.887  score:0.216
#      ❌ cell phone           → book                 | IoU:0.063  score:0.047
#      ⭕ keyboard             → keyboard             | IoU:0.907  score:0.755
#      ⭕ scissors             → scissors             | IoU:0.713  score:0.705
#      ⭕ toothbrush           → toothbrush           | IoU:0.435  score:0.296
#      정답 5/6  img_score:0.3615
#
#   📁 image_006
#      ❌ book                 → 미탐지                  | IoU:0.000  score:0.000
#      ❌ bottle               → mouse                | IoU:0.730  score:0.110
#      ⭕ cell phone           → cell phone           | IoU:0.899  score:0.177
#      ⭕ keyboard             → keyboard             | IoU:0.873  score:0.740
#      ❌ laptop               → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ scissors             → scissors             | IoU:0.941  score:0.930
#      ⭕ toothbrush           → toothbrush           | IoU:0.702  score:0.135
#      ⭕ toothbrush           → toothbrush           | IoU:0.828  score:0.576
#      정답 5/8  img_score:0.3335
#
#
# =================================================================
#   🤖 YOLO11n-seg 평가 중...
# =================================================================
#   📁 image_001
#      ⭕ book                 → book                 | IoU:0.932  score:0.524
#      ❌ bottle               → 미탐지                  | IoU:0.000  score:0.000
#      ❌ hair drier           → keyboard             | IoU:0.002  score:0.002
#      ❌ handbag              → laptop               | IoU:0.876  score:0.486
#      ❌ keyboard             → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ mouse                → mouse                | IoU:0.000  score:0.000
#      ⭕ mouse                → mouse                | IoU:0.000  score:0.000
#      ❌ scissors             → 미탐지                  | IoU:0.000  score:0.000
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      정답 3/9  img_score:0.1124
#
#   📁 image_002
#      ⭕ book                 → book                 | IoU:0.892  score:0.134
#      ❌ bottle               → suitcase             | IoU:0.001  score:0.000
#      ❌ hair drier           → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ keyboard             → keyboard             | IoU:0.570  score:0.457
#      ⭕ mouse                → mouse                | IoU:0.561  score:0.167
#      ⭕ scissors             → scissors             | IoU:0.741  score:0.414
#      ⭕ toothbrush           → toothbrush           | IoU:0.320  score:0.071
#      정답 5/7  img_score:0.1778
#
#   📁 image_003
#      ⭕ book                 → book                 | IoU:0.806  score:0.239
#      ❌ bottle               → 미탐지                  | IoU:0.000  score:0.000
#      ❌ hair drier           → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ handbag              → handbag              | IoU:0.985  score:0.551
#      ⭕ keyboard             → keyboard             | IoU:0.913  score:0.414
#      ⭕ mouse                → mouse                | IoU:0.307  score:0.143
#      ⭕ scissors             → scissors             | IoU:0.935  score:0.748
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      정답 5/8  img_score:0.2619
#
#   📁 image_004
#      ❌ book                 → 미탐지                  | IoU:0.000  score:0.000
#      ❌ cell phone           → 미탐지                  | IoU:0.000  score:0.000
#      ❌ hair drier           → 미탐지                  | IoU:0.000  score:0.000
#      ❌ handbag              → tv                   | IoU:0.833  score:0.407
#      ⭕ keyboard             → keyboard             | IoU:0.855  score:0.691
#      ⭕ scissors             → scissors             | IoU:0.684  score:0.373
#      ⭕ toothbrush           → toothbrush           | IoU:0.000  score:0.000
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      정답 3/8  img_score:0.1840
#
#   📁 image_005
#      ⭕ book                 → book                 | IoU:0.605  score:0.501
#      ❌ bottle               → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ cell phone           → cell phone           | IoU:0.424  score:0.104
#      ⭕ keyboard             → keyboard             | IoU:0.957  score:0.743
#      ⭕ scissors             → scissors             | IoU:0.744  score:0.481
#      ⭕ toothbrush           → toothbrush           | IoU:0.442  score:0.085
#      정답 5/6  img_score:0.3192
#
#   📁 image_006
#      ❌ book                 → laptop               | IoU:0.267  score:0.163
#      ❌ bottle               → 미탐지                  | IoU:0.000  score:0.000
#      ⭕ cell phone           → cell phone           | IoU:0.952  score:0.241
#      ⭕ keyboard             → keyboard             | IoU:0.862  score:0.761
#      ⭕ laptop               → laptop               | IoU:0.906  score:0.501
#      ⭕ scissors             → scissors             | IoU:0.926  score:0.721
#      ⭕ toothbrush           → toothbrush           | IoU:0.000  score:0.000
#      ❌ toothbrush           → 미탐지                  | IoU:0.000  score:0.000
#      정답 5/8  img_score:0.2983
#
# ✅ 전체 평가 완료

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---
# ## 시각화 — Confusion Matrix
# - **Y축**: True label (GT)
# - **X축**: Predicted label
# - 미탐지는 `(미탐지)` 컬럼으로 표시

# %%
def draw_confusion_matrix(model_name, img_results):
    """Confusion Matrix 시각화 및 Precision/Recall 계산"""
    pair_counts  = defaultdict(int)
    gt_label_set = set()
    pred_label_set = set()

    for img_r in img_results:
        for r in img_r['eval_results']:
            gt   = r['gt_label']
            pred = r['pred_label'] if r['pred_label'] else '(미탐지)'
            pair_counts[(gt, pred)] += 1
            gt_label_set.add(gt)
            pred_label_set.add(pred)

    true_labels = sorted(gt_label_set)
    pred_labels = sorted(pred_label_set - {'(미탐지)'}) + \
                  (['(미탐지)'] if '(미탐지)' in pred_label_set else [])

    matrix = np.zeros((len(true_labels), len(pred_labels)), dtype=int)
    for (gt, pred), cnt in pair_counts.items():
        matrix[true_labels.index(gt), pred_labels.index(pred)] += cnt

    # Precision / Recall 계산
    cm_precision, cm_recall = {}, {}
    for label in true_labels:
        r_idx   = true_labels.index(label)
        tp      = matrix[r_idx, pred_labels.index(label)] if label in pred_labels else 0
        row_sum = matrix[r_idx].sum()
        col_sum = matrix[:, pred_labels.index(label)].sum() if label in pred_labels else 0
        cm_recall[label]    = float(tp / row_sum) if row_sum > 0 else 0.0
        cm_precision[label] = float(tp / col_sum) if col_sum > 0 else 0.0

    macro_p  = float(np.mean(list(cm_precision.values())))
    macro_r  = float(np.mean(list(cm_recall.values())))
    macro_f1 = (2 * macro_p * macro_r / (macro_p + macro_r)
                if (macro_p + macro_r) > 0 else 0.0)

    # 시각화
    fig_h = max(5, len(true_labels) * 0.7 + 2)
    fig_w = max(7, len(pred_labels) * 0.9 + 2)
    fig, ax = plt.subplots(figsize=(fig_w, fig_h))
    ax.imshow(matrix, cmap='Blues', aspect='auto', vmin=0)

    COLOR_MAP = {
        'miss'   : '#e74c3c',
        'correct': '#2ecc71',
        'wrong'  : '#e67e22',
    }

    for r in range(len(true_labels)):
        for c in range(len(pred_labels)):
            val = matrix[r, c]
            if val == 0:
                ax.add_patch(plt.Rectangle((c - 0.5, r - 0.5), 1, 1,
                             facecolor='#f8f9fa', edgecolor='#dee2e6', linewidth=0.5))
                continue
            pred_l = pred_labels[c]
            if pred_l == '(미탐지)':
                color = COLOR_MAP['miss']
            elif true_labels[r] == pred_l:
                color = COLOR_MAP['correct']
            else:
                color = COLOR_MAP['wrong']
            ax.add_patch(plt.Rectangle((c - 0.5, r - 0.5), 1, 1,
                         facecolor=color, edgecolor='white', linewidth=1.0, alpha=0.85))
            ax.text(c, r, str(val), ha='center', va='center',
                    fontsize=13, fontweight='bold', color='white')

    ax.set_xticks(range(len(pred_labels)))
    ax.set_yticks(range(len(true_labels)))
    ax.set_xticklabels(pred_labels, rotation=35, ha='right', fontsize=10)
    ax.set_yticklabels(true_labels, fontsize=10)
    ax.set_xlabel('Predicted Label', fontsize=12, fontweight='bold', labelpad=10)
    ax.set_ylabel('True Label (GT)', fontsize=12, fontweight='bold', labelpad=10)
    ax.set_title(f'[{model_name}] Confusion Matrix', fontsize=14, fontweight='bold', pad=15)
    ax.set_xticks(np.arange(-0.5, len(pred_labels), 1), minor=True)
    ax.set_yticks(np.arange(-0.5, len(true_labels), 1), minor=True)
    ax.grid(which='minor', color='#dee2e6', linewidth=0.8)
    ax.tick_params(which='minor', length=0)
    ax.legend(handles=[
        mpatches.Patch(facecolor=COLOR_MAP['correct'], label='✅ 정답 (GT==PRED)'),
        mpatches.Patch(facecolor=COLOR_MAP['wrong'],   label='⚠️  오탐 (GT≠PRED)'),
        mpatches.Patch(facecolor=COLOR_MAP['miss'],    label='❌ 미탐지'),
    ], loc='upper right', bbox_to_anchor=(1.0, -0.18), fontsize=9, ncol=3)
    plt.tight_layout()

    fname = f'output_confusion_{model_name.replace(" ", "_")}.png'
    plt.savefig(OUT / fname, dpi=150, bbox_inches='tight')
    plt.show()
    print(f'✅ 저장: {OUT}/{fname}')

    # 요약 수치 출력
    total   = sum(pair_counts.values())
    correct = sum(cnt for (gt, pred), cnt in pair_counts.items() if gt == pred)
    missed  = sum(cnt for (gt, pred), cnt in pair_counts.items() if pred == '(미탐지)')
    wrong   = total - correct - missed
    print(f'  정답(GT==PRED) : {correct}/{total}  ({correct/total:.1%})')
    print(f'  오탐(라벨 틀림): {wrong}/{total}  ({wrong/total:.1%})')
    print(f'  미탐지         : {missed}/{total}  ({missed/total:.1%})')

    return true_labels, cm_precision, cm_recall, macro_p, macro_r, macro_f1


# ── 모델별 실행
cm_store = {}

for model_name, img_results in ALL_RESULTS.items():
    print(f"\n{'='*55}")
    print(f'  🤖 {model_name}')
    print(f"{'='*55}")
    true_labels, cm_precision, cm_recall, macro_p, macro_r, macro_f1 = \
        draw_confusion_matrix(model_name, img_results)
    cm_store[model_name] = {
        'true_labels' : true_labels,
        'cm_precision': cm_precision,
        'cm_recall'   : cm_recall,
        'macro_p'     : macro_p,
        'macro_r'     : macro_r,
        'macro_f1'    : macro_f1,
    }

print('\n✅ Confusion Matrix 완료')
# Out:
# =======================================================
#   🤖 YOLO11x-seg
# =======================================================
# ✅ 저장: results/output_confusion_YOLO11x-seg.png
#   정답(GT==PRED) : 27/46  (58.7%)
#   오탐(라벨 틀림): 6/46  (13.0%)
#   미탐지         : 13/46  (28.3%)
#
# =======================================================
#   🤖 YOLO11-bh
# =======================================================
# ✅ 저장: results/output_confusion_YOLO11-bh.png
#   정답(GT==PRED) : 32/46  (69.6%)
#   오탐(라벨 틀림): 8/46  (17.4%)
#   미탐지         : 6/46  (13.0%)
#
# =======================================================
#   🤖 YOLO11-full
# =======================================================
# ✅ 저장: results/output_confusion_YOLO11-full.png
#   정답(GT==PRED) : 22/46  (47.8%)
#   오탐(라벨 틀림): 17/46  (37.0%)
#   미탐지         : 7/46  (15.2%)
#
# =======================================================
#   🤖 YOLO26x-seg
# =======================================================
# ✅ 저장: results/output_confusion_YOLO26x-seg.png
#   정답(GT==PRED) : 29/46  (63.0%)
#   오탐(라벨 틀림): 4/46  (8.7%)
#   미탐지         : 13/46  (28.3%)
#
# =======================================================
#   🤖 YOLO_coco_stop-seg
# =======================================================
# ✅ 저장: results/output_confusion_YOLO_coco_stop-seg.png
#   정답(GT==PRED) : 27/46  (58.7%)
#   오탐(라벨 틀림): 6/46  (13.0%)
#   미탐지         : 13/46  (28.3%)
#
# =======================================================
#   🤖 YOLO_coco_full-seg
# =======================================================
# ✅ 저장: results/output_confusion_YOLO_coco_full-seg.png
#   정답(GT==PRED) : 32/46  (69.6%)
#   오탐(라벨 틀림): 9/46  (19.6%)
#   미탐지         : 5/46  (10.9%)
#
# =======================================================
#   🤖 YOLO11n-seg
# =======================================================
# ✅ 저장: results/output_confusion_YOLO11n-seg.png
#   정답(GT==PRED) : 26/46  (56.5%)
#   오탐(라벨 틀림): 5/46  (10.9%)
#   미탐지         : 15/46  (32.6%)
#
# ✅ Confusion Matrix 완료

# %% [markdown]
# ---
# ## 시각화 — Precision / Recall / F1 막대 그래프

# %%
def draw_pr_bar(model_name, store):
    labels    = store['true_labels']
    prec_vals = [store['cm_precision'][l] for l in labels]
    rec_vals  = [store['cm_recall'][l]    for l in labels]
    f1_vals   = [2*p*r/(p+r) if (p+r) > 0 else 0.0
                 for p, r in zip(prec_vals, rec_vals)]
    macro_p, macro_r, macro_f1 = store['macro_p'], store['macro_r'], store['macro_f1']

    x, w = np.arange(len(labels)), 0.26
    fig, ax = plt.subplots(figsize=(max(10, len(labels) * 2.0), 6))

    bars = [
        ax.bar(x - w, prec_vals, w, label='Precision', color='#9b59b6', alpha=0.87),
        ax.bar(x,     rec_vals,  w, label='Recall',    color='#f39c12', alpha=0.87),
        ax.bar(x + w, f1_vals,   w, label='F1 Score',  color='#3498db', alpha=0.87),
    ]
    for bar_group in bars:
        for b in bar_group:
            h = b.get_height()
            if h > 0.01:
                ax.text(b.get_x() + b.get_width() / 2, h + 0.01, f'{h:.3f}',
                        ha='center', va='bottom', fontsize=8, fontweight='bold')

    ax.axhline(macro_p,  color='#9b59b6', linestyle='--', linewidth=1.3,
               label=f'macro Precision:{macro_p:.3f}')
    ax.axhline(macro_r,  color='#f39c12', linestyle='--', linewidth=1.3,
               label=f'macro Recall:{macro_r:.3f}')
    ax.axhline(macro_f1, color='#3498db', linestyle=':',  linewidth=1.3,
               label=f'macro F1:{macro_f1:.3f}')

    ax.set_xticks(x)
    ax.set_xticklabels(labels, rotation=30, ha='right', fontsize=10)
    ax.set_ylim(0, 1.25)
    ax.set_ylabel('값', fontsize=11)
    ax.legend(fontsize=9)
    ax.set_title(f'[{model_name}] Precision / Recall / F1',
                 fontsize=12, fontweight='bold')
    plt.tight_layout()

    fname = f'output_pr_{model_name.replace(" ", "_")}.png'
    plt.savefig(OUT / fname, dpi=150, bbox_inches='tight')
    plt.show()
    print(f'✅ 저장: {OUT}/{fname}')


for model_name, store in cm_store.items():
    print(f"\n{'='*55}")
    print(f'  🤖 {model_name}')
    print(f"{'='*55}")
    draw_pr_bar(model_name, store)

print('\n✅ PR 막대그래프 완료')
# Out:
# =======================================================
#   🤖 YOLO11x-seg
# =======================================================
# ✅ 저장: results/output_pr_YOLO11x-seg.png
#
# =======================================================
#   🤖 YOLO11-bh
# =======================================================
# ✅ 저장: results/output_pr_YOLO11-bh.png
#
# =======================================================
#   🤖 YOLO11-full
# =======================================================
# ✅ 저장: results/output_pr_YOLO11-full.png
#
# =======================================================
#   🤖 YOLO26x-seg
# =======================================================
# ✅ 저장: results/output_pr_YOLO26x-seg.png
#
# =======================================================
#   🤖 YOLO_coco_stop-seg
# =======================================================
# ✅ 저장: results/output_pr_YOLO_coco_stop-seg.png
#
# =======================================================
#   🤖 YOLO_coco_full-seg
# =======================================================
# ✅ 저장: results/output_pr_YOLO_coco_full-seg.png
#
# =======================================================
#   🤖 YOLO11n-seg
# =======================================================
# ✅ 저장: results/output_pr_YOLO11n-seg.png
#
# ✅ PR 막대그래프 완료

# %% [markdown]
# ---
# ## 시각화 — Precision / Recall / F1 Heatmap

# %%
def draw_pr_heatmap(model_name, store):
    true_labels = store['true_labels']
    prec_h = [store['cm_precision'][l] for l in true_labels]
    rec_h  = [store['cm_recall'][l]    for l in true_labels]
    f1_h   = [2*p*r/(p+r) if (p+r) > 0 else 0.0 for p, r in zip(prec_h, rec_h)]
    data   = np.array([prec_h, rec_h, f1_h]).T  # shape (n_labels, 3)

    col_labels     = ['Precision', 'Recall', 'F1']
    n_labels, n_cols = len(true_labels), 3
    cmap = mcolors.LinearSegmentedColormap.from_list('rg', ['#e74c3c', '#f39c12', '#2ecc71'])

    fig, ax = plt.subplots(figsize=(7, max(4, n_labels * 0.55 + 2.5)))
    im = ax.imshow(data, cmap=cmap, aspect='auto', vmin=0, vmax=1)

    for r in range(n_labels):
        for c in range(n_cols):
            val = data[r, c]
            ax.text(c, r, f'{val:.4f}', ha='center', va='center',
                    fontsize=10, fontweight='bold',
                    color='white' if val < 0.6 else 'black')

    ax.set_xticks(range(n_cols))
    ax.set_xticklabels(col_labels, fontsize=12, fontweight='bold')
    ax.set_yticks(range(n_labels))
    ax.set_yticklabels(true_labels, fontsize=10)
    ax.xaxis.set_ticks_position('top')
    ax.xaxis.set_label_position('top')
    ax.set_xticks(np.arange(-0.5, n_cols, 1),    minor=True)
    ax.set_yticks(np.arange(-0.5, n_labels, 1),  minor=True)
    ax.grid(which='minor', color='white', linewidth=1.5)
    ax.tick_params(which='minor', length=0)

    cbar = fig.colorbar(im, ax=ax, fraction=0.03, pad=0.02)
    cbar.set_label('Score', fontsize=10)
    cbar.set_ticks([0, 0.25, 0.5, 0.75, 1.0])

    macro_p, macro_r, macro_f1 = store['macro_p'], store['macro_r'], store['macro_f1']
    macro_str = f'Precision:{macro_p:.4f}  Recall:{macro_r:.4f}  F1:{macro_f1:.4f}'
    ax.set_title(f'[{model_name}] Precision / Recall / F1 Heatmap',
                 fontsize=12, fontweight='bold', pad=18)
    fig.text(0.5, 0.01, f'Macro 평균  |  {macro_str}',
             ha='center', fontsize=9, color='#555555',
             bbox=dict(boxstyle='round,pad=0.4', facecolor='#f0f0f0', alpha=0.8))
    plt.tight_layout(rect=[0, 0.04, 1, 1])

    fname = f'output_heatmap_{model_name.replace(" ", "_")}.png'
    plt.savefig(OUT / fname, dpi=150, bbox_inches='tight')
    plt.show()
    print(f'✅ 저장: {OUT}/{fname}')


for model_name, store in cm_store.items():
    print(f"\n{'='*55}")
    print(f'  🤖 {model_name}')
    print(f"{'='*55}")
    draw_pr_heatmap(model_name, store)

print('\n✅ Heatmap 완료')
# Out:
# =======================================================
#   🤖 YOLO11x-seg
# =======================================================
# ✅ 저장: results/output_heatmap_YOLO11x-seg.png
#
# =======================================================
#   🤖 YOLO11-bh
# =======================================================
# ✅ 저장: results/output_heatmap_YOLO11-bh.png
#
# =======================================================
#   🤖 YOLO11-full
# =======================================================
# ✅ 저장: results/output_heatmap_YOLO11-full.png
#
# =======================================================
#   🤖 YOLO26x-seg
# =======================================================
# ✅ 저장: results/output_heatmap_YOLO26x-seg.png
#
# =======================================================
#   🤖 YOLO_coco_stop-seg
# =======================================================
# ✅ 저장: results/output_heatmap_YOLO_coco_stop-seg.png
#
# =======================================================
#   🤖 YOLO_coco_full-seg
# =======================================================
# ✅ 저장: results/output_heatmap_YOLO_coco_full-seg.png
#
# =======================================================
#   🤖 YOLO11n-seg
# =======================================================
# ✅ 저장: results/output_heatmap_YOLO11n-seg.png
#
# ✅ Heatmap 완료

# %% [markdown]
# ---
# ## OUTPUT — 모델별 성능 결과

# %%
# ── 전체 성능 요약
summary = {}

for model_name, img_results in ALL_RESULTS.items():
    all_rs  = [r for ir in img_results for r in ir['eval_results']]
    correct = sum(1 for r in all_rs if r['gt_label'] == r['pred_label'])
    total   = len(all_rs)
    summary[model_name] = {
        'correct'  : correct,
        'total'    : total,
        'label_acc': correct / total if total else 0.0,
        'avg_score': float(np.mean([r['score'] for r in all_rs])) if all_rs else 0.0,
        'avg_iou'  : float(np.mean([r['iou']   for r in all_rs])) if all_rs else 0.0,
    }

ranked = sorted(summary.items(),
                key=lambda x: (x[1]['label_acc'], x[1]['avg_score']),
                reverse=True)

W_COL = 72
print('\n' + '=' * W_COL)
print(f"  {'모델명':22} {'정답률':>12} {'정답/전체':>12} {'avg score':>12} {'avg IoU':>10}")
print('=' * W_COL)
for rank, (name, s) in enumerate(ranked):
    crown = ' 👑' if rank == 0 else f'  {rank+1} '
    print(f" {crown} {name:20} {s['label_acc']:>12.1%} "
          f"   {s['correct']:>4}/{s['total']:<4}   "
          f"{s['avg_score']:>12.4f} {s['avg_iou']:>10.4f}")
print('=' * W_COL)

# ── label별 정답률 (모델별)
for model_name, img_results in ALL_RESULTS.items():
    all_rs   = [r for ir in img_results for r in ir['eval_results']]
    by_label = defaultdict(list)
    for r in all_rs:
        by_label[r['gt_label']].append(r)

    print(f'\n  [{model_name}] label별 정답률')
    print(f"  {'label':25} {'정답률':>8} {'정답/전체':>10} {'avg score':>12}")
    print('  ' + '-' * 57)
    for label in sorted(by_label):
        rs  = by_label[label]
        cor = sum(1 for r in rs if r['gt_label'] == r['pred_label'])
        acc = cor / len(rs)
        sc  = float(np.mean([r['score'] for r in rs]))
        bar = '█' * int(acc * 10) + '░' * (10 - int(acc * 10))
        print(f"  {label:25} {acc:>8.1%}   {cor:>3}/{len(rs):<3}  {bar}  {sc:.4f}")

print('\n✅ 성능 요약 완료')
# Out:
# ========================================================================
#   모델명                             정답률        정답/전체    avg score    avg IoU
# ========================================================================
#   👑 YOLO11-bh                   69.6%      32/46           0.3872     0.6244
#    2  YOLO_coco_full-seg          69.6%      32/46           0.2971     0.5348
#    3  YOLO26x-seg                 63.0%      29/46           0.3103     0.5251
#    4  YOLO11x-seg                 58.7%      27/46           0.3317     0.4467
#    5  YOLO_coco_stop-seg          58.7%      27/46           0.2000     0.4119
#    6  YOLO11n-seg                 56.5%      26/46           0.2201     0.3978
#    7  YOLO11-full                 47.8%      22/46           0.3461     0.5164
# ========================================================================
#
#   [YOLO11x-seg] label별 정답률
#   label                          정답률      정답/전체    avg score
#   ---------------------------------------------------------
#   book                        100.0%     6/6    ██████████  0.4448
#   bottle                        0.0%     0/5    ░░░░░░░░░░  0.0005
#   cell phone                  100.0%     3/3    ██████████  0.4476
#   hair drier                    0.0%     0/4    ░░░░░░░░░░  0.0004
#   handbag                      66.7%     2/3    ██████░░░░  0.5813
#   keyboard                     66.7%     4/6    ██████░░░░  0.5270
#   laptop                      100.0%     1/1    ██████████  0.7750
#   mouse                        50.0%     2/4    █████░░░░░  0.2133
#   scissors                     83.3%     5/6    ████████░░  0.6426
#   toothbrush                   50.0%     4/8    █████░░░░░  0.1068
#
#   [YOLO11-bh] label별 정답률
#   label                          정답률      정답/전체    avg score
#   ---------------------------------------------------------
#   book                         50.0%     3/6    █████░░░░░  0.1986
#   bottle                      100.0%     5/5    ██████████  0.6237
#   cell phone                  100.0%     3/3    ██████████  0.4069
#   hair drier                    0.0%     0/4    ░░░░░░░░░░  0.1496
#   handbag                      66.7%     2/3    ██████░░░░  0.6738
#   keyboard                     83.3%     5/6    ████████░░  0.5427
#   laptop                      100.0%     1/1    ██████████  0.1697
#   mouse                        50.0%     2/4    █████░░░░░  0.3502
#   scissors                    100.0%     6/6    ██████████  0.6037
#   toothbrush                   62.5%     5/8    ██████░░░░  0.1517
#
#   [YOLO11-full] label별 정답률
#   label                          정답률      정답/전체    avg score
#   ---------------------------------------------------------
#   book                          0.0%     0/6    ░░░░░░░░░░  0.0701
#   bottle                      100.0%     5/5    ██████████  0.3872
#   cell phone                   66.7%     2/3    ██████░░░░  0.2906
#   hair drier                  100.0%     4/4    ██████████  0.6791
#   handbag                       0.0%     0/3    ░░░░░░░░░░  0.0930
#   keyboard                      0.0%     0/6    ░░░░░░░░░░  0.1426
#   laptop                      100.0%     1/1    ██████████  0.1654
#   mouse                         0.0%     0/4    ░░░░░░░░░░  0.2405
#   scissors                     33.3%     2/6    ███░░░░░░░  0.5298
#   toothbrush                  100.0%     8/8    ██████████  0.5670
#
#   [YOLO26x-seg] label별 정답률
#   label                          정답률      정답/전체    avg score
#   ---------------------------------------------------------
#   book                        100.0%     6/6    ██████████  0.6766
#   bottle                       60.0%     3/5    ██████░░░░  0.1312
#   cell phone                   66.7%     2/3    ██████░░░░  0.1362
#   hair drier                    0.0%     0/4    ░░░░░░░░░░  0.0001
#   handbag                      33.3%     1/3    ███░░░░░░░  0.1307
#   keyboard                     66.7%     4/6    ██████░░░░  0.5585
#   laptop                        0.0%     0/1    ░░░░░░░░░░  0.1501
#   mouse                       100.0%     4/4    ██████████  0.2765
#   scissors                     83.3%     5/6    ████████░░  0.5488
#   toothbrush                   50.0%     4/8    █████░░░░░  0.1071
#
#   [YOLO_coco_stop-seg] label별 정답률
#   label                          정답률      정답/전체    avg score
#   ---------------------------------------------------------
#   book                         16.7%     1/6    █░░░░░░░░░  0.0338
#   bottle                       40.0%     2/5    ████░░░░░░  0.0947
#   cell phone                   33.3%     1/3    ███░░░░░░░  0.0545
#   hair drier                   75.0%     3/4    ███████░░░  0.1353
#   handbag                       0.0%     0/3    ░░░░░░░░░░  0.0002
#   keyboard                     83.3%     5/6    ████████░░  0.2186
#   laptop                        0.0%     0/1    ░░░░░░░░░░  0.0000
#   mouse                       100.0%     4/4    ██████████  0.6377
#   scissors                     83.3%     5/6    ████████░░  0.4983
#   toothbrush                   75.0%     6/8    ███████░░░  0.1210
#
#   [YOLO_coco_full-seg] label별 정답률
#   label                          정답률      정답/전체    avg score
#   ---------------------------------------------------------
#   book                         66.7%     4/6    ██████░░░░  0.1060
#   bottle                       40.0%     2/5    ████░░░░░░  0.1657
#   cell phone                   33.3%     1/3    ███░░░░░░░  0.0758
#   hair drier                   75.0%     3/4    ███████░░░  0.3732
#   handbag                       0.0%     0/3    ░░░░░░░░░░  0.0073
#   keyboard                    100.0%     6/6    ██████████  0.4575
#   laptop                        0.0%     0/1    ░░░░░░░░░░  0.0000
#   mouse                       100.0%     4/4    ██████████  0.7003
#   scissors                     83.3%     5/6    ████████░░  0.5397
#   toothbrush                   87.5%     7/8    ████████░░  0.2094
#
#   [YOLO11n-seg] label별 정답률
#   label                          정답률      정답/전체    avg score
#   ---------------------------------------------------------
#   book                         66.7%     4/6    ██████░░░░  0.2602
#   bottle                        0.0%     0/5    ░░░░░░░░░░  0.0000
#   cell phone                   66.7%     2/3    ██████░░░░  0.1149
#   hair drier                    0.0%     0/4    ░░░░░░░░░░  0.0005
#   handbag                      33.3%     1/3    ███░░░░░░░  0.4815
#   keyboard                     83.3%     5/6    ████████░░  0.5111
#   laptop                      100.0%     1/1    ██████████  0.5010
#   mouse                       100.0%     4/4    ██████████  0.0776
#   scissors                     83.3%     5/6    ████████░░  0.4562
#   toothbrush                   50.0%     4/8    █████░░░░░  0.0196
#
# ✅ 성능 요약 완료

# %% [markdown]
# ---
# ## 시각화 — Label별 평균 IoU / Precision / Recall (전체 모델 통합)

# %%
label_stats = defaultdict(list)
for img_results in ALL_RESULTS.values():
    for img_r in img_results:
        for r in img_r['eval_results']:
            label_stats[r['gt_label']].append(r)

lnames = sorted(label_stats.keys())
l_iou  = [float(np.mean([r['iou']       for r in label_stats[l]])) for l in lnames]
l_prec = [float(np.mean([r['precision'] for r in label_stats[l]])) for l in lnames]
l_rec  = [float(np.mean([r['recall']    for r in label_stats[l]])) for l in lnames]

x, w = np.arange(len(lnames)), 0.26
fig, ax = plt.subplots(figsize=(max(20, len(lnames) * 2.5), 10))

bars = [
    ax.bar(x - w, l_iou,  w, label='IoU',       color='#3498db', alpha=0.85),
    ax.bar(x,     l_prec, w, label='Precision',  color='#9b59b6', alpha=0.85),
    ax.bar(x + w, l_rec,  w, label='Recall',     color='#f39c12', alpha=0.85),
]
for bar_group in bars:
    for b in bar_group:
        h = b.get_height()
        if h > 0.01:
            ax.text(b.get_x() + b.get_width() / 2, h + 0.01, f'{h:.3f}',
                    ha='center', va='bottom', fontsize=6.5)

ax.set_xticks(x)
ax.set_xticklabels(lnames, rotation=30, ha='right', fontsize=10)
ax.set_ylim(0, 1.25)
ax.set_ylabel('값', fontsize=11)
ax.legend(fontsize=9)
ax.set_title('Label별 평균 IoU / Precision / Recall  (전체 모델 통합)',
             fontsize=12, fontweight='bold')
plt.tight_layout()
plt.savefig(OUT / 'output_label_score.png', dpi=150, bbox_inches='tight')
plt.show()
print(f'✅ 저장: {OUT}/output_label_score.png')
# Out:
# ✅ 저장: results/output_label_score.png
